# %% [markdown]
# # Process the data

# %%
import numpy as np

# %%
with open('dtu data_final.csv', 'r') as f:
    data = [i.split("\n") for i in f.read().split()]

# %%
for a in data:
    print a
# Out:
# ['Habitat;ADHD;Diabetes;OTC;Branded;Rygestop;Astma;RX;Region;Chain;Modul']
# ['Mindre']
# ['provinsby;1465251,95;2620860,57;3012945,02;2253343,14;266363,52;2799588,72;21094421,02;Hovedstaden;Chain1;60']
# ['Mindre']
# ['provinsby;948084,26;2047946,54;2747744,69;1717534,57;301175,33;2226292,65;15121483,26;Hovedstaden;Chain1;60']
# ['Mindre']
# ['provinsby;427579,22;1147016,56;1776477,74;863744,02;233996,44;1497227,51;9102757,55;Hovedstaden;Chain1;60']
# ['Metropol;110045,14;736229,73;1485083,45;1403053,3;247009,99;959326,95;8352191,3;Hovedstaden;Chain1;59']
# ['Metropol;67073,55;296163,79;1380581,95;1582787,96;212966,08;319258,06;2649204,65;Hovedstaden;Chain1;59']
# ['Metropolomegn;16581,87;48898,85;187800,32;179723,02;36968,94;66160,48;422907,97;Hovedstaden;Chain1;59']
# ['Metropolomegn;804552,78;4193941,73;4930155,7;3388539,58;770014,44;4389910,82;31731656,49;Hovedstaden;Chain2;59']
# ...
